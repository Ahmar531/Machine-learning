# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Social_Network_Ads.csv")
df.loc[156, "EstimatedSalary"] = 200000
print(df.loc[156])
# Out:
# User ID            15791174
# Gender                 Male
# Age                      46
# EstimatedSalary      200000
# Purchased                 0
# Name: 156, dtype: object

# %%
sns.scatterplot(x="Age", y="EstimatedSalary", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.boxplot(x=df['EstimatedSalary'])
# Out:
# <Axes: xlabel='EstimatedSalary'>

# %%
df=df.iloc[:,-3:]

# %%
print(df)
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 263   35            72000          0
# 77    22            27000          0
# 383   49            28000          1
# 92    26            15000          0
# 161   25            90000          0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df.drop("Purchased",axis=1), df['Purchased'],test_size=0.3,random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler=MinMaxScaler()

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# from sklearn.preprocessing import RobustScaler
# scaler=RobustScaler()



sc=scaler.fit(X_train)

X_train_scaled=sc.transform(X_train)
X_test_scaled=sc.transform(X_test)

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)

X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9         783882.1
# std     10.2       11948162.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          71000.0
# 75%     46.0          88000.0
# max     60.0      200000000.0

# %%
X_test_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.771013        -0.058430
# 1    0.013305        -0.061532
# 2   -0.280814        -0.059436
# 3   -0.771013        -0.059101
# 4   -0.280814        -0.061532
# ..        ...              ...
# 115  1.091743        -0.060274
# 116  0.699584        -0.054741
# 117 -0.672973        -0.058262
# 118  0.797624        -0.058849
# 119  0.895664        -0.061448
#
# [120 rows x 2 columns]

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -0.064467
# 1    2.170181        -0.057172
# 2    0.013305        -0.056334
# 3    0.209385        -0.056753
# 4    0.405465        -0.061281
# ..        ...              ...
# 275  0.993704        -0.063209
# 276 -0.869053        -0.062119
# 277 -0.182774        -0.061364
# 278 -1.065133        -0.061197
# 279 -1.163172        -0.055831
#
# [280 rows x 2 columns]

# %%
sns.scatterplot(x="Age", y="EstimatedSalary", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
print(X_train_scaled.loc[156])
# Out:
# Age                1.974102
# EstimatedSalary   -0.057759
# Name: 156, dtype: float64
